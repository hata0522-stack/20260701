# %%
print("Hello! Python")
# Out:
# Hello! Python

# %%
#雙向選擇
a = 13
if a >= 14:
    a -= 2
    print(a)
else:
    a += 2
    print(a)
# Out:
# 15

# %%
#單向選擇
age = 15
if age >= 18:
    print("我已經可以投票")
print("應用程式結束")
# Out:
# 應用程式結束
